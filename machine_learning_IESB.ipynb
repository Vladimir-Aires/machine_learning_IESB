# %% [markdown]
# <a href="https://colab.research.google.com/github/Vladimir-Aires/machine_learning_IESB/blob/main/machine_learning_IESB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

churn_df = pd.read_csv('./telecom_churn_clean.csv')
churn_df.head(20)
# Out:
#     Unnamed: 0  account_length  area_code  international_plan  \
# 0            0             128        415                   0
# 1            1             107        415                   0
# 2            2             137        415                   0
# 3            3              84        408                   1
# 4            4              75        415                   1
# 5            5             118        510                   1
# 6            6             121        510                   0
# 7            7             147        415                   1
# 8            8             117        408                   0
# 9            9             141        415                   1
# 10          10              65        415                   0
# 11          11              74        415                   0
# 12          12             168        408                   0
# 13          13              95        510                   0
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
x = churn_df[["total_day_charge", "total_eve_charge"]].values
y = churn_df["churn"].values

print(x.shape, y.shape)
# Out:
# (3333, 2) (3333,)

# %%
from sklearn.neighbors import KNeighborsClassifier

y = churn_df["churn"].values
x = churn_df[["account_length", "customer_service_calls"]].values

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x, y)
# Out:
# KNeighborsClassifier()

# %%
import numpy as np

X_new = np.array([
    [30.0, 17.5],
    [107.0, 24.1],
    [213.0, 10.9]
])

# Predição dos rótulos para os valores em X_new

y_pred = knn.predict(X_new)

print("Predições: {}".format(y_pred))
# Out:
# Predições: [1 1 0]

# %% [markdown]
# # Aula 6 - Regressão | Aprendizado supervisionado com scikit learn

# %%
import pandas as pd
diabetes_df = pd.read_csv('diabetes_clean.csv')


dadosFiltrados = diabetes_df[
    (diabetes_df['bmi'] > 0)
    & (diabetes_df['glucose'] > 0)
]

diabetes_df = dadosFiltrados
# Out:
#     pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0             6      148         72       35        0  33.6  0.627   50
# 1             1       85         66       29        0  26.6  0.351   31
# 2             8      183         64        0        0  23.3  0.672   32
# 3             1       89         66       23       94  28.1  0.167   21
# 4             0      137         40       35      168  43.1  2.288   33
# 5             5      116         74        0        0  25.6  0.201   30
# 6             3       78         50       32       88  31.0  0.248   26
# 7            10      115          0        0        0  35.3  0.134   29
# 8             2      197         70       45      543  30.5  0.158   53
# 10            4      110         92        0        0  37.6  0.191   30
# 11           10      168         74        0        0  38.0  0.537   34
# 12           10      139         80        0        0  27.1  1.441   57
# ...

# %%
X = diabetes_df.drop("glucose", axis=1).values
Y = diabetes_df["glucose"].values

print(type(X), type(Y))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
X_bmi = X[:, 4]
print(Y.shape, X_bmi.shape)
# Out:
# (768,) (768,)

# %%
X_bmi = X_bmi.reshape(-1, 1)
print(Y.shape, X_bmi.shape)
# Out:
# (768,) (768, 1)

# %%
import matplotlib.pyplot as plt
plt.scatter(X_bmi, Y)
plt.ylabel("Blood Glucose (mg/dL)")
plt.xlabel("Body Mass Index")

plt.show()

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_bmi, Y)
predictions = reg.predict(X_bmi)

plt.scatter(X_bmi, Y)
plt.plot(X_bmi, predictions)
plt.ylabel("Blood Glucose (mg/dl)")
plt.xlabel("Body Mass Index")
plt.show()

# %%
import numpy as np
import pandas as pd

sales_df = pd.read_csv("advertising_and_sales_clean.csv")

# 10 observações
sales_df.head(10)
# Out:
#         tv     radio  social_media influencer      sales
# 0  16000.0   6566.23       2907.98       Mega   54732.76
# 1  13000.0   9237.76       2409.57       Mega   46677.90
# 2  41000.0  15886.45       2913.41       Mega  150177.83
# 3  83000.0  30020.03       6922.30       Mega  298246.34
# 4  15000.0   8437.41       1406.00      Micro   56594.18
# 5  29000.0   9614.38       1027.16       Mega  105889.15
# 6  55000.0  24893.81       4273.60      Micro  198679.82
# 7  31000.0  17355.04       2289.85       Nano  108733.93
# 8  76000.0  24648.90       7130.12      Macro  270189.40
# 9  13000.0    431.13       2229.42       Mega   48280.58
